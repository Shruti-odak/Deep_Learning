# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')


import tensorflow as tf
from tensorflow.keras import Sequential # used to build ANN
from tensorflow.keras.layers import Dense # used to add hidden layers
from sklearn.metrics import classification_report

# %%
df = pd.read_csv("avocado.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df.shape
# Out:
# (18249, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
# There are no missing values in this data.

df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
# Feature engineering 

df['Date']=pd.to_datetime(df['Date'])
df['Month']=df['Date'].apply(lambda x:x.month)
df['Day']=df['Date'].apply(lambda x:x.day)

# %%
df.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Month  Day
# 0  Albany     12   27
# 1  Albany     12   20
# 2  Albany     12   13
# 3  Albany     12    6
# ...

# %%
# By using pairplot we can find out relationship between the features.

sns.pairplot(data=df,hue="AveragePrice")

# %%
df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
# Month             0.162409     -0.024689 -0.025803 -0.022108 -0.033424
# Day               0.027386     -0.009747 -0.010159 -0.012393 -0.009009
#
# ...

# %%
df.sample(5)
# Out:
#             Date  AveragePrice  Total Volume        4046       4225      4770  \
# 11914 2015-05-10          1.43      13607.51     5881.71    4326.02      6.90
# 1754  2015-04-05          0.57    1320320.85  1058164.41  172115.69   7128.12
# 12445 2016-02-21          1.33      10563.94      529.00    7783.07      0.00
# 5120  2016-07-10          1.08     389300.41   168421.00   87043.24  21153.33
# 8502  2018-03-25          1.23     986038.75   108250.52  591934.75   4205.03
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 11914     3392.88     1853.33     1539.55         0.00       organic  2015
# 1754     82912.63    49271.61    33641.02         0.00  conventional  2015
# 12445     2251.87      348.67     1903.20         0.00       organic  2016
# 5120    112682.84    89946.17    22731.67         5.00  conventional  2016
# 8502    281648.45   277508.08     2777.04      1363.33  conventional  2018
#
#                     region  Month  Day
# ...

# %%
plt.figure(figsize=(17,8))
plt.xticks(rotation=90)
sns.countplot(df['region'])
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %%
# As we have extracted Month , year and dayfrom Date column. 

df.drop(columns=["Date"],inplace=True)

# %%
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags          type  year  region  Month  Day
# 0     8603.62       93.25          0.0  conventional  2015  Albany     12   27
# 1     9408.07       97.49          0.0  conventional  2015  Albany     12   20
# 2     8042.21      103.14          0.0  conventional  2015  Albany     12   13
# 3     5677.40      133.76          0.0  conventional  2015  Albany     12    6
# 4     5986.26      197.69          0.0  conventional  2015  Albany     11   29

# %%
cat_col=df.select_dtypes(include=["object"])
cat_col
# Out:
#                type            region
# 0      conventional            Albany
# 1      conventional            Albany
# 2      conventional            Albany
# 3      conventional            Albany
# 4      conventional            Albany
# ...             ...               ...
# 18244       organic  WestTexNewMexico
# 18245       organic  WestTexNewMexico
# 18246       organic  WestTexNewMexico
# 18247       organic  WestTexNewMexico
# 18248       organic  WestTexNewMexico
#
# [18249 rows x 2 columns]

# %%
# Label encoding

from sklearn.preprocessing import LabelEncoder

# %%
# Converted region and type column into numerical.

for i in cat_col:
 le=LabelEncoder()
 df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year  region  Month  Day
# ...

# %%
# Seperating x and y

x=df.iloc[:,1:]
x
# Out:
#        Total Volume     4046       4225    4770  Total Bags  Small Bags  \
# 0          64236.62  1036.74   54454.85   48.16     8696.87     8603.62
# 1          54876.98   674.28   44638.81   58.33     9505.56     9408.07
# 2         118220.22   794.70  109149.67  130.50     8145.35     8042.21
# 3          78992.15  1132.00   71976.41   72.58     5811.16     5677.40
# 4          51039.60   941.48   43838.39   75.78     6183.95     5986.26
# ...             ...      ...        ...     ...         ...         ...
# 18244      17074.83  2046.96    1529.20    0.00    13498.67    13066.82
# 18245      13888.04  1191.70    3431.50    0.00     9264.84     8940.04
# 18246      13766.76  1191.92    2452.79  727.94     9394.11     9351.80
# 18247      16205.22  1527.63    2981.04  727.01    10969.54    10919.54
# 18248      17489.58  2894.77    2356.13  224.53    12014.15    11988.14
#
#        Large Bags  XLarge Bags  type  year  region  Month  Day
# ...

# %%
y = df['AveragePrice']
y
# Out:
# 0        1.33
# 1        1.35
# 2        0.93
# 3        1.08
# 4        1.28
#          ...
# 18244    1.63
# 18245    1.71
# 18246    1.87
# 18247    1.93
# 18248    1.62
# Name: AveragePrice, Length: 18249, dtype: float64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
xtrain=sc.fit_transform(xtrain)
xtest=sc.transform(xtest)

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

# %%
ann=Sequential()

ann.add(Dense(units=6,activation="relu"))
ann.add(Dense(units=6,activation="relu"))

ann.add(Dense(units=1))

ann.compile(optimizer="adam", loss="mse")

ann.fit(xtrain,ytrain,epochs=1000,validation_data=(xtest, ytest),verbose=1,batch_size=128,callbacks=[early_stop])
# Out:
# Epoch 1/1000
# 100/100 [==============================] - 2s 5ms/step - loss: 0.7457 - val_loss: 0.3208
# Epoch 2/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2178 - val_loss: 0.1773
# Epoch 3/1000
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1596 - val_loss: 0.1474
# Epoch 4/1000
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1368 - val_loss: 0.1284
# Epoch 5/1000
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1209 - val_loss: 0.1144
# Epoch 6/1000
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1087 - val_loss: 0.1035
# Epoch 7/1000
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1002 - val_loss: 0.0974
# Epoch 8/1000
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0953 - val_loss: 0.0933
# Epoch 9/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0919 - val_loss: 0.0903
# Epoch 10/1000
# ...

# %%
loss=ann.history.history

# %%
ypred=ann.predict(xtest)
# Out:
# 172/172 [==============================] - 0s 2ms/step

# %%
ypred
# Out:
# array([[1.7241366],
#        [1.0128073],
#        [1.0982143],
#        ...,
#        [1.6548247],
#        [1.3603504],
#        [1.3224438]], dtype=float32)

# %%
pd.DataFrame({"Actual value":ytest,"predicted value":ypred.flatten()})
# Out:
#        Actual value  predicted value
# 14192          2.11         1.724137
# 1873           0.98         1.012807
# 7293           1.17         1.098214
# 15087          1.78         1.657339
# 9888           1.61         1.704389
# ...             ...              ...
# 8645           0.92         1.075969
# 14649          1.59         1.544920
# 12558          1.47         1.654825
# 13464          2.07         1.360350
# 6091           1.16         1.322444
#
# [5475 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(ytest,ypred)
# Out:
# 0.6173409800683198
